# %%
import numpy as np

# %%
# Scalar Arighmatic

# %%
arr = np.array([1,2,3])

# %%
arr+1 # array([2, 3, 4]); adds 1 to all the elements
# Out:
# array([2, 3, 4])

# %%
arr-2
# Out:
# array([-1,  0,  1])

# %%
arr*2
# Out:
# array([2, 4, 6])

# %%
arr/2
# Out:
# array([0.5, 1. , 1.5])

# %%
arr**4
# Out:
# array([ 1, 16, 81])

# %%
# Vectorized Math Functions

# %%
np.sqrt(arr) # square root of all the array element
# Out:
# array([1.        , 1.41421356, 1.73205081])

# %%
# round() = Rounds to nearest integer [4.6 → 5, 4.4 → 4]
# floor() = Always rounds down [4.9 → 4]
# ceil() = Always rounds up  [4.1 → 5]

# %%
arr = np.array([1.34, 2.78, 3.50])

# %%
np.round(arr) # 1.34 → 1, 2.78 → 3, and 3.50 → 4
# Out:
# array([1., 3., 4.])

# %%
np.floor(arr) # 1.34 → 1, 2.78 → 2, and 3 → 4
# Out:
# array([1., 2., 3.])

# %%
np.ceil(arr) # 1.34 → 2, 2.78 → 3, and 3.50 → 4
# Out:
# array([2., 3., 4.])

# %%
np.pi # will return the value of pi = 3.1416....
# Out:
# 3.141592653589793

# %%
# Excercise
# Given array is the list of radius of circles
# Find the area of the circles.

# %%
radius = np.array([2,3,4])
np.pi*radius**2
# Out:
# array([12.56637061, 28.27433388, 50.26548246])

# %%
# Element-wise arithmatic

# %%
arr1 = np.array([1,2,3])
arr2 = np.array([4,5,6])

# %%
arr1 + arr2
# Out:
# array([5, 7, 9])

# %%
arr1 - arr2
# Out:
# array([-3, -3, -3])

# %%
arr1 * arr2
# Out:
# array([ 4, 10, 18])

# %%
arr1 / arr2
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
arr1 ** arr2
# Out:
# array([  1,  32, 729])

# %%
# Comparison Operator

# %%
scores = np.array([32, 45, 67, 87, 23, 56, 82, 96, 87, 99, 100])

# %%
scores >= 40
# Out:
# array([False,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True])

# %%
scores < 40
# Out:
# array([ True, False, False, False,  True, False, False, False, False,
#        False, False])

# %%
scores[scores < 40]
# Out:
# array([32, 23])

# %%
scores[scores < 40] = 0
scores
# Out:
# array([  0,  45,  67,  87,   0,  56,  82,  96,  87,  99, 100])
