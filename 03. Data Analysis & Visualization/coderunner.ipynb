# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array(['A', 'B', 'C', 'D', 'E', 'F'])
y = np.array([1, 2, 5, 3, 4, 6])
style = dict(
    color='red',
    markerfacecolor='black',
    markeredgecolor='green',
    marker = '.',
    markersize='20'
)
plt.bar(x, y)
plt.show()
