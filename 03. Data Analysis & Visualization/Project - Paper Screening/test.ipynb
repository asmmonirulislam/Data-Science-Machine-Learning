# %%
import pandas as pd

# %%
try:
    df1 = pd.read_csv("IEEEXplore_01.csv")
    df2 = pd.read_csv("IEEEXplore_02.csv")
except Exception as e:
    print(e)
else:
    print("File exported")
# Out:
# File exported

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Document Title          83 non-null     object
#  1   Authors                 83 non-null     object
#  2   Author Affiliations     83 non-null     object
#  3   Publication Title       83 non-null     object
#  4   Date Added To Xplore    83 non-null     object
#  5   Publication Year        83 non-null     int64
#  6   Volume                  62 non-null     float64
#  7   Issue                   19 non-null     float64
#  8   Start Page              83 non-null     int64
#  9   End Page                83 non-null     int64
#  10  Abstract                83 non-null     object
#  11  ISSN                    73 non-null     object
#  12  ISBNs                   21 non-null     object
#  13  DOI                     83 non-null     object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        9 non-null      object
#  1   Unnamed: 1   9 non-null      object
#  2   Unnamed: 2   9 non-null      object
#  3   Unnamed: 3   9 non-null      object
#  4   Unnamed: 4   9 non-null      object
#  5   Year         9 non-null      int64
#  6   Unnamed: 6   5 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   9 non-null      int64
#  9   Unnamed: 9   9 non-null      int64
#  10  abstract     9 non-null      object
#  11  Unnamed: 11  7 non-null      object
#  12  Unnamed: 12  4 non-null      object
#  13  Unnamed: 13  9 non-null      object
#  14  Unnamed: 14  5 non-null      object
#  15  Unnamed: 15  9 non-null      object
#  16  Unnamed: 16  9 non-null      object
#  17  Unnamed: 17  9 non-null      object
# ...

# %%
pd.set_option('display.max_colwidth', None)
title_list = df2['title'].to_list()
title_list
# Out:
# ['Comparing Abstract and Realistic Agent-Led Instructions for Language Learning in Virtual Environments: A Study on Presence Effects',
#  'Advancing Engineering Education Through Serious Games: A Systematic Literature Review of Technological Innovation, Challenges, and Future Directions',
#  'Design and Implementation of Metaverse for a Self-Learning Platform: a Case Study in KMUTNB Techno Park',
#  'Impact of Different UI on Foreign Language Learning Using iVR',
#  'Learning a Foreign Language: Traditional Listening vs Interactive Immersive Virtual Reality',
#  'Improving Higher Education With the Use of Mobile Augmented Reality (MAR): A Case Study',
#  'Interactive Augmented Reality System for Learning Phonetics Using Artificial Intelligence',
#  'Teaching EFL With Immersive Virtual Reality Technologies: A Comparison With the Conventional Listening Method',
#  'Game-based learning using a 3D virtual world in computer engineering education']

# %%
for i, row in df1.iterrows():
    if row['Document Title'] not in title_list:
        df1.drop(i, axis=0, inplace=True)

# %%
len(df1)
# Out:
# 9
