# %%
import pandas as pd

# %%
data = [10, 20, 30]

# %%
s1 = pd.Series(data)
s1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s2 = pd.Series(data, index=['A', 'B', 'C'])
s2
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
#loc[] = location by label
# iloc[] = integer-location based indexing

# %%
s2.loc['B']
# Out:
# np.int64(20)

# %%
s2.iloc[2]
# Out:
# np.int64(30)

# %%
s2.iloc[2]=40
s2
# Out:
# A    10
# B    20
# C    40
# dtype: int64

# %%
s1.iloc[1]=55
s1
# Out:
# 0    10
# 1    55
# 2    30
# dtype: int64
