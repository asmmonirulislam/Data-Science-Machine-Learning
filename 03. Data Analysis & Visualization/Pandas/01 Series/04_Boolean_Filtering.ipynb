# %%
import pandas as pd

# %%
data = [100, 200, 300, 400, 500]
series = pd.Series(data)
series
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
series[series<300]
# Out:
# 0    100
# 1    200
# dtype: int64

# %%
series[(series>=300) & (series<=400)]
# Out:
# 2    300
# 3    400
# dtype: int64

# %%
series[series.between(300, 400)]
# Out:
# 2    300
# 3    400
# dtype: int64

# %%
series.iloc[3]+=300
series
# Out:
# 0    100
# 1    200
# 2    300
# 3    700
# 4    500
# dtype: int64
