# %%
# DataFrame = A  tabular data structure with rows AND columns (2-Dimensional)
# Similar to an Excel Spreadsheet

# %%
import pandas as pd

# %%
data = {
    'Name': ['Monirul', 'Sayem', 'Hafiza', 'Mim'],
    'Roll' : [3982, 2981, 3973, 2973],
    'Age' : [24, 25, 22, 21],
    'CGPA' : [3.99, 4.00, 3.87, 2.78]
}

data
# Out:
# {'Name': ['Monirul', 'Sayem', 'Hafiza', 'Mim'],
#  'Roll': [3982, 2981, 3973, 2973],
#  'Age': [24, 25, 22, 21],
#  'CGPA': [3.99, 4.0, 3.87, 2.78]}

# %%
df = pd.DataFrame(data)


df
# Out:
#       Name  Roll  Age  CGPA
# 0  Monirul  3982   24  3.99
# 1    Sayem  2981   25  4.00
# 2   Hafiza  3973   22  3.87
# 3      Mim  2973   21  2.78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Roll    4 non-null      int64
#  2   Age     4 non-null      int64
#  3   CGPA    4 non-null      float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 260.0+ bytes

# %%
df.loc[3]
# Out:
# Name     Mim
# Roll    2973
# Age       21
# CGPA    2.78
# Name: 3, dtype: object
